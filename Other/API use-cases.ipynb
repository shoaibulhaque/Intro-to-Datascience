# %% [markdown]
# # Simple APIs
# ## Random User and Fruitvice API Examples

# %% [markdown]
# The advantages of using APIs:
#  *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more
#      productive.
#  *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#      independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#  *   **Secirity**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data
#      breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# **To start using the API you can install the `randomuser` library running the `pip install` command.**

# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5067 sha256=b005e4bf790b3fbb2fbf38765a973ba6606448c6a5d85c729595b2d16bc835c2
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/f8/a9/23/1df3ef7a5177d99b4cba8fa52415e1360bde68f520c2a0e489
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
# from randomuser import RandomUser
# import pandas as pd

from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
# r = RandomUser()
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
# some_list = r.generate_users(10)


some_list = r.generate_users(10) # --> returns a list

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7f858978bd90>,
#  <randomuser.RandomUser at 0x7f858978bdd0>,
#  <randomuser.RandomUser at 0x7f858978be10>,
#  <randomuser.RandomUser at 0x7f858978be50>,
#  <randomuser.RandomUser at 0x7f858978be90>,
#  <randomuser.RandomUser at 0x7f858978bf10>,
#  <randomuser.RandomUser at 0x7f858978bf50>,
#  <randomuser.RandomUser at 0x7f858978bf90>,
#  <randomuser.RandomUser at 0x7f858978bfd0>,
#  <randomuser.RandomUser at 0x7f858978bed0>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
# name = r.get_full_name()

name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
# for user in some_list:
#     print (user.get_full_name()," ",user.get_email())

for user in some_list:
    print(user.get_full_name(), " ", user.get_email())
# Out:
# Vildan Kuday   vildan.kuday@example.com
# Eléna Noel   elena.noel@example.com
# Philip Jean-Baptiste   philip.jean-baptiste@example.com
# Kuzey Eliçin   kuzey.elicin@example.com
# Begüm Kılıççı   begum.kilicci@example.com
# Macit Özdoğan   macit.ozdogan@example.com
# Sharron Stanley   sharron.stanley@example.com
# Ece Kavaklıoğlu   ece.kavaklioglu@example.com
# Muriëlle Van Manen   murielle.vanmanen@example.com
# Enrico Durand   enrico.durand@example.com

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 5 users.

# %%
import os
import requests

# This script generates 10 random user pictures using RandomUserAPI then creates new folder and save them in that

def save_to_folder(url_list):
    count = 0
    for url in url_list:
        r = requests.get(url)
        img_path = os.path.join(os.getcwd(), path + f"/image{count + 1}.png")
        with open(img_path, 'wb') as file:
            file.write(r.content)
        count += 1
    return

# create a path, os.getcwd()_--> current working directory
path = os.path.join(os.getcwd(), 'Images')
if not os.path.exists(path):
    os.mkdir(path)
    
# os.chdir(path)
# print(os.getcwd())
url_List = [user.get_picture() for user in some_list]
save_to_folder(url_List)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)     

# def user_table():
#     users = RandomUser.generate_users(10)
#     users = {"Name:": [user.get_full_name() for user in users], "Gender": [user.get_gender() for user in users],"City":[user.get_city() for user in users] , "State": [user.get_state() for user in users], "Email": [user.get_email() for user in users]}
#     return pd.DataFrame(users)

# %%
get_users()
# Out:
#               Name  Gender                  City                State  \
# 0    Fred Silveira    male                Palmas                Amapá
# 1   Rosane Freitas  female             Arapongas       Rio de Janeiro
# 2     Murat Paksüt    male                 Iğdır           Kırklareli
# 3     Jaime Alonso    male            Torrevieja  Comunidad de Madrid
# 4    Emily Coleman  female        Stoke-on-Trent        Hertfordshire
# 5   Amber Matthews  female             Wakefield             Cornwall
# 6  Nelita Monteiro  female  Aparecida de Goiânia     Distrito Federal
# 7     Devin Oosten    male             Bergen Nh              Zeeland
# 8  David Pelletier    male             Killarney              Nunavut
# 9     Josep Suarez    male            Pontevedra              Navarra
#
#                          Email                       DOB  \
# 0    fred.silveira@example.com  1997-03-08T20:25:47.812Z
# 1   rosane.freitas@example.com  1972-06-21T06:55:37.838Z
# 2     murat.paksut@example.com  1978-01-26T11:50:41.167Z
# 3     jaime.alonso@example.com  1974-04-22T10:42:31.379Z
# 4    emily.coleman@example.com  1954-10-10T14:02:56.465Z
# 5   amber.matthews@example.com  1953-03-25T20:59:01.639Z
# 6  nelita.monteiro@example.com  1993-01-28T16:19:28.548Z
# 7     devin.oosten@example.com  1974-10-14T17:31:03.328Z
# 8  david.pelletier@example.com  1966-09-13T04:45:29.346Z
# 9     josep.suarez@example.com  1985-11-07T21:19:04.974Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/65.jpg
# 1  https://randomuser.me/api/portraits/women/45.jpg
# 2    https://randomuser.me/api/portraits/men/13.jpg
# 3    https://randomuser.me/api/portraits/men/33.jpg
# 4  https://randomuser.me/api/portraits/women/34.jpg
# 5  https://randomuser.me/api/portraits/women/13.jpg
# 6  https://randomuser.me/api/portraits/women/27.jpg
# 7     https://randomuser.me/api/portraits/men/6.jpg
# 8     https://randomuser.me/api/portraits/men/2.jpg
# 9    https://randomuser.me/api/portraits/men/47.jpg

# %%
df1 = pd.DataFrame(get_users())
df1
# Out:
#               Name  Gender                City        State  \
# 0    Jasmine Brown  female            Hamilton  Hawke'S Bay
# 1     یاسمین پارسا  female                 خوی       اصفهان
# 2   Myriam Möhring  female  Erlangen-Höchstadt    Thüringen
# 3   Andrew Perkins    male           Wakefield        Gwent
# 4   محمدمهدی یاسمی    male              بروجرد        البرز
# 5      Chris Young    male             Sallins      Leitrim
# 6    Lionel Fleury    male          Fischingen     Obwalden
# 7      Rose Walker  female           Stratford      Ontario
# 8  Ankie Den Ouden  female            Hoogwoud   Gelderland
# 9      ایلیا موسوی    male                 یزد      هرمزگان
#
#                         Email                       DOB  \
# 0   jasmine.brown@example.com  1960-01-15T07:26:07.240Z
# 1       ysmyn.prs@example.com  1968-10-18T15:11:51.280Z
# 2  myriam.mohring@example.com  1989-01-31T21:07:41.979Z
# 3  andrew.perkins@example.com  1972-01-13T16:06:03.157Z
# 4   mhmdmhdy.ysmy@example.com  1963-02-15T21:33:35.586Z
# 5     chris.young@example.com  1946-11-25T12:24:07.850Z
# 6   lionel.fleury@example.com  1965-07-05T09:51:46.627Z
# 7     rose.walker@example.com  1981-08-27T00:11:42.511Z
# 8  ankie.denouden@example.com  1993-10-18T15:14:47.543Z
# 9       yly.mwswy@example.com  1948-05-07T03:05:28.335Z
#
#                                             Picture
# 0   https://randomuser.me/api/portraits/women/4.jpg
# 1  https://randomuser.me/api/portraits/women/83.jpg
# 2  https://randomuser.me/api/portraits/women/36.jpg
# 3    https://randomuser.me/api/portraits/men/26.jpg
# 4    https://randomuser.me/api/portraits/men/61.jpg
# 5     https://randomuser.me/api/portraits/men/8.jpg
# 6    https://randomuser.me/api/portraits/men/87.jpg
# 7  https://randomuser.me/api/portraits/women/51.jpg
# 8  https://randomuser.me/api/portraits/women/42.jpg
# 9    https://randomuser.me/api/portraits/men/74.jpg

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")
data
# Out:
# '[{"name":"Persimmon","id":52,"family":"Ebenaceae","order":"Rosales","genus":"Diospyros","nutritions":{"calories":81,"fat":0.0,"sugar":18.0,"carbohydrates":18.0,"protein":0.0}},{"name":"Strawberry","id":3,"family":"Rosaceae","order":"Rosales","genus":"Fragaria","nutritions":{"calories":29,"fat":0.4,"sugar":5.4,"carbohydrates":5.5,"protein":0.8}},{"name":"Banana","id":1,"family":"Musaceae","order":"Zingiberales","genus":"Musa","nutritions":{"calories":96,"fat":0.2,"sugar":17.2,"carbohydrates":22.0,"protein":1.0}},{"name":"Tomato","id":5,"family":"Solanaceae","order":"Solanales","genus":"Solanum","nutritions":{"calories":74,"fat":0.2,"sugar":2.6,"carbohydrates":3.9,"protein":0.9}},{"name":"Pear","id":4,"family":"Rosaceae","order":"Rosales","genus":"Pyrus","nutritions":{"calories":57,"fat":0.1,"sugar":10.0,"carbohydrates":15.0,"protein":0.4}},{"name":"Durian","id":60,"family":"Malvaceae","order":"Malvales","genus":"Durio","nutritions":{"calories":147,"fat":5.3,"sugar":6.75,"carbohydrates":27.1,"protein":1.5}},{"name":"Blackberry","id":64,"family":"Rosaceae","order":"Rosales","genus":"Rubus","nutritions":{"calories":40,"fat":0.4,"sugar":4.5,"carbohydrates":9.0,"protein":1.3}},{"name":"Lingonberry","id":65,"family":"Ericaceae","order":"Ericales","genus":"Vaccinium","nutritions":{"calories":50,"fat":0.34,"sugar":5.74,"carbohydrates":11.3,"protein":0.75}},{"name":"Kiwi","id":66,"family":"Actinidiaceae","order":"Struthioniformes","genus":"Apteryx","nutritions":{"calories":61,"fat":0.5,"sugar":9.0,"carbohydrates":15.0,"protein":1.1}},{"name":"Lychee","id":67,"family":"Sapindaceae","order":"Sapindales","genus":"Litchi","nutritions":{"calories":66,"fat":0.44,"sugar":15.0,"carbohydrates":17.0,"protein":0.8}},{"name":"Pineapple","id":10,"family":"Bromeliaceae","order":"Poales","genus":"Ananas","nutritions":{"calories":50,"fat":0.12,"sugar":9.85,"carbohydrates":13.12,"protein":0.54}},{"name":"Fig","id":68,"family":"Moraceae","order":"Rosales","genus":"Ficus","nutritions":{"calories":74,"fat":0.3,"sugar":16.0,"carbohydrates":19.0,"protein":0.8}},{"name":"Gooseberry","id":69,"family":"Grossulariaceae","order":"Saxifragales","genus":"Ribes","nutritions":{"calories":44,"fat":0.6,"sugar":0.0,"carbohydrates":10.0,"protein":0.9}},{"name":"Passionfruit","id":70,"family":"Passifloraceae","order":"Malpighiales","genus":"Passiflora","nutritions":{"calories":97,"fat":0.7,"sugar":11.2,"carbohydrates":22.4,"protein":2.2}},{"name":"Plum","id":71,"family":"Rosaceae","order":"Rosales","genus":"Prunus","nutritions":{"calories":46,"fat":0.28,"sugar":9.92,"carbohydrates":11.4,"protein":0.7}},{"name":"Orange","id":2,"family":"Rutaceae","order":"Sapindales","genus":"Citrus","nutritions":{"calories":43,"fat":0.2,"sugar":8.2,"carbohydrates":8.3,"protein":1.0}},{"name":"GreenApple","id":72,"family":"Rosaceae","order":"Rosales","genus":"Malus","nutritions":{"calories":21,"fat":0.1,"sugar":6.4,"carbohydrates":3.1,"protein":0.4}},{"name":"Raspberry","id":23,"family":"Rosaceae","order":"Rosales","genus":"Rubus","nutritions":{"calories":53,"fat":0.7,"sugar":4.4,"carbohydrates":12.0,"protein":1.2}},{"name":"Watermelon","id":25,"family":"Cucurbitaceae","order":"Cucurbitales","genus":"Citrullus","nutritions":{"calories":30,"fat":0.2,"sugar":6.0,"carbohydrates":8.0,"protein":0.6}},{"name":"Lemon","id":26,"family":"Rutaceae","order":"Sapindales","genus":"Citrus","nutritions":{"calories":29,"fat":0.3,"sugar":2.5,"carbohydrates":9.0,"protein":1.1}},{"name":"Mango","id":27,"family":"Anacardiaceae","order":"Sapindales","genus":"Mangifera","nutritions":{"calories":60,"fat":0.38,"sugar":13.7,"carbohydrates":15.0,"protein":0.82}},{"name":"Blueberry","id":33,"family":"Rosaceae","order":"Rosales","genus":"Fragaria","nutritions":{"calories":29,"fat":0.4,"sugar":5.4,"carbohydrates":5.5,"protein":0.0}},{"name":"Apple","id":6,"family":"Rosaceae","order":"Rosales","genus":"Malus","nutritions":{"calories":52,"fat":0.4,"sugar":10.3,"carbohydrates":11.4,"protein":0.3}},{"name":"Guava","id":3 ...

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)
# Out:
# [{'name': 'Persimmon', 'id': 52, 'family': 'Ebenaceae', 'order': 'Rosales', 'genus': 'Diospyros', 'nutritions': {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'carbohydrates': 18.0, 'protein': 0.0}}, {'name': 'Strawberry', 'id': 3, 'family': 'Rosaceae', 'order': 'Rosales', 'genus': 'Fragaria', 'nutritions': {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'carbohydrates': 5.5, 'protein': 0.8}}, {'name': 'Banana', 'id': 1, 'family': 'Musaceae', 'order': 'Zingiberales', 'genus': 'Musa', 'nutritions': {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'carbohydrates': 22.0, 'protein': 1.0}}, {'name': 'Tomato', 'id': 5, 'family': 'Solanaceae', 'order': 'Solanales', 'genus': 'Solanum', 'nutritions': {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'carbohydrates': 3.9, 'protein': 0.9}}, {'name': 'Pear', 'id': 4, 'family': 'Rosaceae', 'order': 'Rosales', 'genus': 'Pyrus', 'nutritions': {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'carbohydrates': 15.0, 'protein': 0.4}}, {'name': 'Durian', 'id': 60, 'family': 'Malvaceae', 'order': 'Malvales', 'genus': 'Durio', 'nutritions': {'calories': 147, 'fat': 5.3, 'sugar': 6.75, 'carbohydrates': 27.1, 'protein': 1.5}}, {'name': 'Blackberry', 'id': 64, 'family': 'Rosaceae', 'order': 'Rosales', 'genus': 'Rubus', 'nutritions': {'calories': 40, 'fat': 0.4, 'sugar': 4.5, 'carbohydrates': 9.0, 'protein': 1.3}}, {'name': 'Lingonberry', 'id': 65, 'family': 'Ericaceae', 'order': 'Ericales', 'genus': 'Vaccinium', 'nutritions': {'calories': 50, 'fat': 0.34, 'sugar': 5.74, 'carbohydrates': 11.3, 'protein': 0.75}}, {'name': 'Kiwi', 'id': 66, 'family': 'Actinidiaceae', 'order': 'Struthioniformes', 'genus': 'Apteryx', 'nutritions': {'calories': 61, 'fat': 0.5, 'sugar': 9.0, 'carbohydrates': 15.0, 'protein': 1.1}}, {'name': 'Lychee', 'id': 67, 'family': 'Sapindaceae', 'order': 'Sapindales', 'genus': 'Litchi', 'nutritions': {'calories': 66, 'fat': 0.44, 'sugar': 15.0, 'carbohydrates': 17.0, 'protein': 0.8}}, {'name': 'Pineapple', 'id': 10, 'family': 'Bromeliaceae', 'order': 'Poales', 'genus': 'Ananas', 'nutritions': {'calories': 50, 'fat': 0.12, 'sugar': 9.85, 'carbohydrates': 13.12, 'protein': 0.54}}, {'name': 'Fig', 'id': 68, 'family': 'Moraceae', 'order': 'Rosales', 'genus': 'Ficus', 'nutritions': {'calories': 74, 'fat': 0.3, 'sugar': 16.0, 'carbohydrates': 19.0, 'protein': 0.8}}, {'name': 'Gooseberry', 'id': 69, 'family': 'Grossulariaceae', 'order': 'Saxifragales', 'genus': 'Ribes', 'nutritions': {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'carbohydrates': 10.0, 'protein': 0.9}}, {'name': 'Passionfruit', 'id': 70, 'family': 'Passifloraceae', 'order': 'Malpighiales', 'genus': 'Passiflora', 'nutritions': {'calories': 97, 'fat': 0.7, 'sugar': 11.2, 'carbohydrates': 22.4, 'protein': 2.2}}, {'name': 'Plum', 'id': 71, 'family': 'Rosaceae', 'order': 'Rosales', 'genus': 'Prunus', 'nutritions': {'calories': 46, 'fat': 0.28, 'sugar': 9.92, 'carbohydrates': 11.4, 'protein': 0.7}}, {'name': 'Orange', 'id': 2, 'family': 'Rutaceae', 'order': 'Sapindales', 'genus': 'Citrus', 'nutritions': {'calories': 43, 'fat': 0.2, 'sugar': 8.2, 'carbohydrates': 8.3, 'protein': 1.0}}, {'name': 'GreenApple', 'id': 72, 'family': 'Rosaceae', 'order': 'Rosales', 'genus': 'Malus', 'nutritions': {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'carbohydrates': 3.1, 'protein': 0.4}}, {'name': 'Raspberry', 'id': 23, 'family': 'Rosaceae', 'order': 'Rosales', 'genus': 'Rubus', 'nutritions': {'calories': 53, 'fat': 0.7, 'sugar': 4.4, 'carbohydrates': 12.0, 'protein': 1.2}}, {'name': 'Watermelon', 'id': 25, 'family': 'Cucurbitaceae', 'order': 'Cucurbitales', 'genus': 'Citrullus', 'nutritions': {'calories': 30, 'fat': 0.2, 'sugar': 6.0, 'carbohydrates': 8.0, 'protein': 0.6}}, {'name': 'Lemon', 'id': 26, 'family': 'Rutaceae', 'order': 'Sapindales', 'genus': 'Citrus', 'nutritions': {'calories': 29, 'fat': 0.3, 'sugar': 2.5, 'carbohydrates': 9.0, 'protein': 1.1}}, {'name': 'Mango', 'id': 27, 'family': 'Anacardiaceae', 'order': 'Sapindales', 'genus': 'Mangifera', 'nutritions': {'cal ...

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# 12    Gooseberry  69  Grossulariaceae      Saxifragales         Ribes
# 13  Passionfruit  70   Passifloraceae      Malpighiales    Passiflora
# 14          Plum  71         Rosaceae           Rosales        Prunus
# 15        Orange   2         Rutaceae        Sapindales        Citrus
# 16    GreenApple  72         Rosaceae           Rosales         Malus
# 17     Raspberry  23         Rosaceae           Rosales         Rubus
# 18    Watermelon  25    Cucurbitaceae      Cucurbitales     Citrullus
# 19         Lemon  26         Rutaceae        Sapindales        Citrus
# 20         Mango  27    Anacardiaceae        Sapindales     Mangifera
# 21     Blueberry  33         Rosaceae           Rosales      Fragaria
# 22         Apple   6         Rosaceae           Rosales         Malus
# 23         Guava  37        Myrtaceae          Myrtales       Psidium
# 24       Apricot  35         Rosaceae           Rosales        Prunus
# 25        Papaya  42       Caricaceae         Caricacea        Carica
# 26         Melon  41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 27     Tangerine  77         Rutaceae        Sapindales        Citrus
# 28      Pitahaya  78        Cactaceae    Caryophyllales     Cactaceae
# 29          Lime  44         Rutaceae        Sapindales        Citrus
# 30   Pomegranate  79       Lythraceae          Myrtales        Punica
# 31   Dragonfruit  80        Cactaceae    Caryophyllales  Selenicereus
# 32         Grape  81         Vitaceae           Vitales         Vitis
# 33         Morus  82         Moraceae           Rosales         Morus
# 34        Feijoa  76        Myrtaceae        Myrtoideae    Sellowiana
# 35       Avocado  84        Lauraceae          Laurales        Persea
# 36     Kiwifruit  85    Actinidiaceae          Ericales     Actinidia
# 37     Cranberry  87        Ericaceae          Ericales     Vaccinium
# 38        Cherry   9         Rosaceae           Rosales        Prunus
# 39         Peach  86         Rosaceae           Rosales        Prunus
#
#                                            nutritions
# 0   {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1   {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2   {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3   {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4   {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...
# 5   {'calories': 147, 'fat': 5.3, 'sugar': 6.75, '...
# 6   {'calories': 40, 'fat': 0.4, 'sugar': 4.5, 'ca...
# 7   {'calories': 50, 'fat': 0.34, 'sugar': 5.74, '...
# 8   {'calories': 61, 'fat': 0.5, 'sugar': 9.0, 'ca...
# 9   {'calories': 66, 'fat': 0.44, 'sugar': 15.0, '...
# 10  {'calories': 50, 'fat': 0.12, 'sugar': 9.85, '...
# 11  {'calories': 74, 'fat': 0.3, 'sugar': 16.0, 'c...
# 12  {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 13  {'calories': 97, 'fat': 0.7, 'sugar': 11.2, 'c...
# 14  {'calories': 46, 'fat': 0.28, 'sugar': 9.92, '...
# 15  {'calories': 43, 'fat': 0.2, 'sugar': 8.2, 'ca...
# 16  {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'ca...
# 17  {'calories': 53, 'fat': 0.7, 'sugar': 4.4, 'ca...
# 18  {'calories': 30, 'fat': 0.2, 'sugar': 6.0, 'ca...
# 19  {'calories': 29, 'fat': 0.3, 'sugar': 2.5, 'ca...
# 20  {'calories': 60, 'fat': 0.38, 'sugar': 13.7, '...
# 21  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 22  {'calories': 52, 'fat': 0.4, 'sugar': 10.3, 'c...
# 23  {'calories': 68, 'fat': 1.0, 'sugar': 9.0, 'ca...
# 24  {'calories': 15, 'fat': 0.1, 'sugar': 3.2, 'ca...
# 25  {'calories': 43, 'fat': 0.4, 'sugar': 1.0, 'ca...
# 26  {'calories': 34, 'fat': 0.0, 'sugar': 8.0, 'ca...
# 27  {'calories': 45, 'fat': 0.4, 'sugar': 9.1, 'ca...
# 28  {'calories': 36, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 29  {'calories': 25, 'fat': 0.1, 'sugar': 1.7, 'ca...
# 30  {'calories': 83, 'fat': 1.2, 'sugar': 13.7, 'c...
# 31  {'calories': 60, 'fat': 1.5, 'sugar': 8.0, 'ca...
# 32  {'calories': 69, 'fat': 0.16, 'sugar': 16.0, '...
# 33  {'calories': 43, 'fat': 0.39, 'sugar': 8.1, 'c...
# 34  {'calories': 44, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 35  {'calories': 160, 'fat': 14.66, 'sugar': 0.66,...
# 36  {'calories': 61, 'fat': 0.5, 'sugar': 8.9, 'ca...
# 37  {'calories': 46, 'fat': 0.1, 'sugar': 4.0, 'ca...
# 38  {'calories': 50, 'fat': 0.3, 'sugar': 8.0, 'ca...
# 39  {'calories': 39, 'fat': 0.25, 'sugar': 8.4, 'c...

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# 12    Gooseberry  69  Grossulariaceae      Saxifragales         Ribes
# 13  Passionfruit  70   Passifloraceae      Malpighiales    Passiflora
# 14          Plum  71         Rosaceae           Rosales        Prunus
# 15        Orange   2         Rutaceae        Sapindales        Citrus
# 16    GreenApple  72         Rosaceae           Rosales         Malus
# 17     Raspberry  23         Rosaceae           Rosales         Rubus
# 18    Watermelon  25    Cucurbitaceae      Cucurbitales     Citrullus
# 19         Lemon  26         Rutaceae        Sapindales        Citrus
# 20         Mango  27    Anacardiaceae        Sapindales     Mangifera
# 21     Blueberry  33         Rosaceae           Rosales      Fragaria
# 22         Apple   6         Rosaceae           Rosales         Malus
# 23         Guava  37        Myrtaceae          Myrtales       Psidium
# 24       Apricot  35         Rosaceae           Rosales        Prunus
# 25        Papaya  42       Caricaceae         Caricacea        Carica
# 26         Melon  41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 27     Tangerine  77         Rutaceae        Sapindales        Citrus
# 28      Pitahaya  78        Cactaceae    Caryophyllales     Cactaceae
# 29          Lime  44         Rutaceae        Sapindales        Citrus
# 30   Pomegranate  79       Lythraceae          Myrtales        Punica
# 31   Dragonfruit  80        Cactaceae    Caryophyllales  Selenicereus
# 32         Grape  81         Vitaceae           Vitales         Vitis
# 33         Morus  82         Moraceae           Rosales         Morus
# 34        Feijoa  76        Myrtaceae        Myrtoideae    Sellowiana
# 35       Avocado  84        Lauraceae          Laurales        Persea
# 36     Kiwifruit  85    Actinidiaceae          Ericales     Actinidia
# 37     Cranberry  87        Ericaceae          Ericales     Vaccinium
# 38        Cherry   9         Rosaceae           Rosales        Prunus
# 39         Peach  86         Rosaceae           Rosales        Prunus
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   43            0.40              1.00
# 26                   34            0.00              8.00
# 27                   45            0.40              9.10
# 28                   36            0.40              3.00
# 29                   25            0.10              1.70
# 30                   83            1.20             13.70
# 31                   60            1.50              8.00
# 32                   69            0.16             16.00
# 33                   43            0.39              8.10
# 34                   44            0.40              3.00
# 35                  160           14.66              0.66
# 36                   61            0.50              8.90
# 37                   46            0.10              4.00
# 38                   50            0.30              8.00
# 39                   39            0.25              8.40
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                     11.00                0.00
# 26                      8.00                0.00
# 27                      8.30                0.00
# 28                      7.00                1.00
# 29                      8.40                0.30
# 30                     18.70                1.70
# 31                      9.00                9.00
# 32                     18.10                0.72
# 33                      9.80                1.44
# 34                      8.00                0.60
# 35                      8.53                2.00
# 36                     14.60                1.14
# 37                     12.20                0.40
# 38                     12.00                1.00
# 39                      9.50                0.90

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
cherry.loc[38]['family']
# Out:
# 'Rosaceae'

# %% [markdown]
# ## Exercise 2
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
banana = df2.loc[df2['name'] == 'Banana'][['nutritions.calories']]
banana
# Out:
#    nutritions.calories
# 2                   96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
# 1. Using `requests.get("url")` function, load your data.

# %%
# # Write your code here
# data = requests.get("https://kontests.net/api/v1/all")
# data.text
# Out:
# '[{"name":"ProjectEuler+","url":"https://hackerrank.com/contests/projecteuler","start_time":"2014-07-07T15:38:00.000Z","end_time":"2024-07-30T18:30:00.000Z","duration":"317616720.0","site":"HackerRank","in_24_hours":"No","status":"CODING"},{"name":"NuHarbor Hackathon","url":"https://polyglot.hackerearth.com/","start_time":"2023-02-25T04:01:00.000Z","end_time":"2023-04-17T10:00:00.000Z","duration":"4427940.0","site":"HackerEarth","in_24_hours":"No","status":"CODING"},{"name":"HCL Volt MX Hackathon 2023","url":"https://voltmx.hackerearth.com/","start_time":"2023-03-13T19:00:00.000Z","end_time":"2023-05-15T06:59:00.000Z","duration":"5399940.0","site":"HackerEarth","in_24_hours":"No","status":"CODING"},{"name":"Namma Yatri Open Mobility Challenge","url":"https://www.hackerearth.com/challenges/hackathon/namma-yatri-open-mobility-challenge-hackerearth-2023/","start_time":"2023-03-28T12:30:00.000Z","end_time":"2023-04-30T18:29:00.000Z","duration":"2872740.0","site":"HackerEarth","in_24_hours":"No","status":"CODING"},{"name":"DAO Global Hackathon 2023","url":"https://daoglobalhackathon.hackerearth.com/","start_time":"2023-04-10T12:00:00.000Z","end_time":"2023-05-07T22:00:00.000Z","duration":"2368800.0","site":"HackerEarth","in_24_hours":"No","status":"CODING"},{"name":"ICPC 2023 Online Spring Challenge powered by Huawei","url":"https://codeforces.com/contestRegistration/1813","start_time":"2023-04-13T11:00:00.000Z","end_time":"2023-04-27T11:00:00.000Z","duration":"1209600","site":"CodeForces","in_24_hours":"Yes","status":"CODING"},{"name":"UTPC Spring 2023 Contest (HS)","url":"https://codeforces.com/gymRegistration/104312","start_time":"2023-04-15T18:00:00.000Z","end_time":"2023-04-15T21:00:00.000Z","duration":"10800","site":"CodeForces::Gym","in_24_hours":"Yes","status":"CODING"},{"name":"UTPC Spring 2023 Open Contest","url":"https://codeforces.com/gymRegistration/104294","start_time":"2023-04-15T18:00:00.000Z","end_time":"2023-04-15T23:00:00.000Z","duration":"18000","site":"CodeForces::Gym","in_24_hours":"Yes","status":"CODING"},{"name":"Weekly Contest 341","url":"https://leetcode.com/contest/weekly-contest-341","start_time":"2023-04-16T02:30:00.000Z","end_time":"2023-04-16T04:00:00.000Z","duration":"5400","site":"LeetCode","in_24_hours":"Yes","status":"BEFORE"},{"name":"Consensus 2023 Hackathon","url":"https://web3athon2023.hackerearth.com/","start_time":"2023-04-17T04:00:00.000Z","end_time":"2023-06-01T03:59:00.000Z","duration":"3887940.0","site":"HackerEarth","in_24_hours":"No","status":"BEFORE"},{"name":"Junglee CodeFest: Unleash Your Skill","url":"https://www.hackerearth.com/challenges/competitive/junglee-games-code-a-thon/","start_time":"2023-04-19T12:30:00.000Z","end_time":"2023-04-23T18:25:00.000Z","duration":"366900.0","site":"HackerEarth","in_24_hours":"No","status":"BEFORE"},{"name":"Starters 86","url":"https://www.codechef.com/START86","start_time":"2023-04-19 14:30:00 UTC","end_time":"2023-04-19 16:30:00 UTC","duration":"7200","site":"CodeChef","in_24_hours":"No","status":"BEFORE"},{"name":"Airbus Aerothon 5.0","url":"https://www.hackerearth.com/challenges/competitive/airbus-aerothon-50/","start_time":"2023-04-20T05:30:00.000Z","end_time":"2023-04-30T17:30:00.000Z","duration":"907200.0","site":"HackerEarth","in_24_hours":"No","status":"BEFORE"},{"name":"Educational Codeforces Round 147 (Rated for Div. 2)","url":"https://codeforces.com/contestRegistration/1821","start_time":"2023-04-20T14:35:00.000Z","end_time":"2023-04-20T16:50:00.000Z","duration":"8100","site":"CodeForces","in_24_hours":"No","status":"BEFORE"},{"name":"Amazon ML Challenge 2023","url":"https://www.hackerearth.com/challenges/competitive/amazon-ml-challenge-2023/","start_time":"2023-04-20T18:30:00.000Z","end_time":"2023-04-23T18:29:00.000Z","duration":"259140.0","site":"HackerEarth","in_24_hours":"No","status":"BEFORE"},{"name":"Tokio Marine \\u0026 Nichido Fire Insurance Programming Contest 2023（AtCoder Beginner Contest 299)","url":"https://atcoder.jp/co ...

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://www.fishwatch.gov/api/species")
# ```
#
# </details>

# %% [markdown]
# 2. Retrieve results using `json.loads()` function.

# %%
# Write your code here
result = json.loads(data.text)
result
# Out:
# [{'name': 'ProjectEuler+',
#   'url': 'https://hackerrank.com/contests/projecteuler',
#   'start_time': '2014-07-07T15:38:00.000Z',
#   'end_time': '2024-07-30T18:30:00.000Z',
#   'duration': '317616720.0',
#   'site': 'HackerRank',
#   'in_24_hours': 'No',
#   'status': 'CODING'},
#  {'name': 'NuHarbor Hackathon',
#   'url': 'https://polyglot.hackerearth.com/',
#   'start_time': '2023-02-25T04:01:00.000Z',
#   'end_time': '2023-04-17T10:00:00.000Z',
#   'duration': '4427940.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'CODING'},
#  {'name': 'HCL Volt MX Hackathon 2023',
#   'url': 'https://voltmx.hackerearth.com/',
#   'start_time': '2023-03-13T19:00:00.000Z',
#   'end_time': '2023-05-15T06:59:00.000Z',
#   'duration': '5399940.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'CODING'},
#  {'name': 'Namma Yatri Open Mobility Challenge',
#   'url': 'https://www.hackerearth.com/challenges/hackathon/namma-yatri-open-mobility-challenge-hackerearth-2023/',
#   'start_time': '2023-03-28T12:30:00.000Z',
#   'end_time': '2023-04-30T18:29:00.000Z',
#   'duration': '2872740.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'CODING'},
#  {'name': 'DAO Global Hackathon 2023',
#   'url': 'https://daoglobalhackathon.hackerearth.com/',
#   'start_time': '2023-04-10T12:00:00.000Z',
#   'end_time': '2023-05-07T22:00:00.000Z',
#   'duration': '2368800.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'CODING'},
#  {'name': 'ICPC 2023 Online Spring Challenge powered by Huawei',
#   'url': 'https://codeforces.com/contestRegistration/1813',
#   'start_time': '2023-04-13T11:00:00.000Z',
#   'end_time': '2023-04-27T11:00:00.000Z',
#   'duration': '1209600',
#   'site': 'CodeForces',
#   'in_24_hours': 'Yes',
#   'status': 'CODING'},
#  {'name': 'UTPC Spring 2023 Contest (HS)',
#   'url': 'https://codeforces.com/gymRegistration/104312',
#   'start_time': '2023-04-15T18:00:00.000Z',
#   'end_time': '2023-04-15T21:00:00.000Z',
#   'duration': '10800',
#   'site': 'CodeForces::Gym',
#   'in_24_hours': 'Yes',
#   'status': 'CODING'},
#  {'name': 'UTPC Spring 2023 Open Contest',
#   'url': 'https://codeforces.com/gymRegistration/104294',
#   'start_time': '2023-04-15T18:00:00.000Z',
#   'end_time': '2023-04-15T23:00:00.000Z',
#   'duration': '18000',
#   'site': 'CodeForces::Gym',
#   'in_24_hours': 'Yes',
#   'status': 'CODING'},
#  {'name': 'Weekly Contest 341',
#   'url': 'https://leetcode.com/contest/weekly-contest-341',
#   'start_time': '2023-04-16T02:30:00.000Z',
#   'end_time': '2023-04-16T04:00:00.000Z',
#   'duration': '5400',
#   'site': 'LeetCode',
#   'in_24_hours': 'Yes',
#   'status': 'BEFORE'},
#  {'name': 'Consensus 2023 Hackathon',
#   'url': 'https://web3athon2023.hackerearth.com/',
#   'start_time': '2023-04-17T04:00:00.000Z',
#   'end_time': '2023-06-01T03:59:00.000Z',
#   'duration': '3887940.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Junglee CodeFest: Unleash Your Skill',
#   'url': 'https://www.hackerearth.com/challenges/competitive/junglee-games-code-a-thon/',
#   'start_time': '2023-04-19T12:30:00.000Z',
#   'end_time': '2023-04-23T18:25:00.000Z',
#   'duration': '366900.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Starters 86',
#   'url': 'https://www.codechef.com/START86',
#   'start_time': '2023-04-19 14:30:00 UTC',
#   'end_time': '2023-04-19 16:30:00 UTC',
#   'duration': '7200',
#   'site': 'CodeChef',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Airbus Aerothon 5.0',
#   'url': 'https://www.hackerearth.com/challenges/competitive/airbus-aerothon-50/',
#   'start_time': '2023-04-20T05:30:00.000Z',
#   'end_time': '2023-04-30T17:30:00.000Z',
#   'duration': '907200.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Educational Codeforces Round 147 (Rated for Div. 2)',
#   'url': 'https://codeforces.com/contestRegistration/1821',
#   'start_time': '2023-04-20T14:35:00.000Z',
#   'end_time': '2023-04-20T16:50:00.000Z',
#   'duration': '8100',
#   'site': 'CodeForces',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Amazon ML Challenge 2023',
#   'url': 'https://www.hackerearth.com/challenges/competitive/amazon-ml-challenge-2023/',
#   'start_time': '2023-04-20T18:30:00.000Z',
#   'end_time': '2023-04-23T18:29:00.000Z',
#   'duration': '259140.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Tokio Marine & Nichido Fire Insurance Programming Contest 2023（AtCoder Beginner Contest 299)',
#   'url': 'https://atcoder.jp/contests/abc299',
#   'start_time': '2023-04-22T12:00:00.000Z',
#   'end_time': '2023-04-22T13:40:00.000Z',
#   'duration': '6000',
#   'site': 'AtCoder',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'ALGO ARTIS Programming Contest 2023（AtCoder Heuristic Contest 020）',
#   'url': 'https://atcoder.jp/contests/ahc020',
#   'start_time': '2023-04-23T06:00:00.000Z',
#   'end_time': '2023-04-23T10:00:00.000Z',
#   'duration': '14400',
#   'site': 'AtCoder',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Tectone23 Hacks',
#   'url': 'https://www.hackerearth.com/challenges/hackathon/tectone23-hacks/',
#   'start_time': '2023-04-24T13:39:00.000Z',
#   'end_time': '2023-05-19T18:25:00.000Z',
#   'duration': '2177160.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Starters 87',
#   'url': 'https://www.codechef.com/START87',
#   'start_time': '2023-04-26 14:30:00 UTC',
#   'end_time': '2023-04-26 16:30:00 UTC',
#   'duration': '7200',
#   'site': 'CodeChef',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'ユニークビジョンプログラミングコンテスト2023 春 (AtCoder Beginner Contest 300)',
#   'url': 'https://atcoder.jp/contests/abc300',
#   'start_time': '2023-04-29T12:00:00.000Z',
#   'end_time': '2023-04-29T13:40:00.000Z',
#   'duration': '6000',
#   'site': 'AtCoder',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Biweekly Contest 103',
#   'url': 'https://leetcode.com/contest/biweekly-contest-103',
#   'start_time': '2023-04-29T14:30:00.000Z',
#   'end_time': '2023-04-29T16:00:00.000Z',
#   'duration': '5400',
#   'site': 'LeetCode',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Codeforces Round (Div. 2)',
#   'url': 'https://codeforces.com/contestRegistration/1818',
#   'start_time': '2023-04-29T14:35:00.000Z',
#   'end_time': '2023-04-29T16:50:00.000Z',
#   'duration': '8100',
#   'site': 'CodeForces',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'Codeforces Round (Div. 1)',
#   'url': 'https://codeforces.com/contestRegistration/1817',
#   'start_time': '2023-04-29T14:35:00.000Z',
#   'end_time': '2023-04-29T16:50:00.000Z',
#   'duration': '8100',
#   'site': 'CodeForces',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'AtCoder Grand Contest 062',
#   'url': 'https://atcoder.jp/contests/agc062',
#   'start_time': '2023-04-30T12:00:00.000Z',
#   'end_time': '2023-04-30T15:00:00.000Z',
#   'duration': '10800',
#   'site': 'AtCoder',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'STARTERS 88',
#   'url': 'https://www.codechef.com/START88',
#   'start_time': '2023-05-03 14:30:00 UTC',
#   'end_time': '2023-05-03 16:30:00 UTC',
#   'duration': '7200',
#   'site': 'CodeChef',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'STARTERS 89',
#   'url': 'https://www.codechef.com/START89',
#   'start_time': '2023-05-10 14:30:00 UTC',
#   'end_time': '2023-05-10 16:30:00 UTC',
#   'duration': '7200',
#   'site': 'CodeChef',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'パナソニックグループプログラミングコンテスト2023（AtCoder Beginner Contest 301）',
#   'url': 'https://atcoder.jp/contests/abc301',
#   'start_time': '2023-05-13T12:00:00.000Z',
#   'end_time': '2023-05-13T13:40:00.000Z',
#   'duration': '6000',
#   'site': 'AtCoder',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'AtCoder Regular Contest 160',
#   'url': 'https://atcoder.jp/contests/arc160',
#   'start_time': '2023-05-14T12:00:00.000Z',
#   'end_time': '2023-05-14T14:00:00.000Z',
#   'duration': '7200',
#   'site': 'AtCoder',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'LGBTQIA+ Matters',
#   'url': 'https://www.hackerearth.com/challenges/hackathon/lgbtqia-matters/',
#   'start_time': '2023-05-17T10:00:00.000Z',
#   'end_time': '2023-05-17T12:00:00.000Z',
#   'duration': '7200.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'STARTERS 90',
#   'url': 'https://www.codechef.com/START90',
#   'start_time': '2023-05-17 14:30:00 UTC',
#   'end_time': '2023-05-17 16:30:00 UTC',
#   'duration': '7200',
#   'site': 'CodeChef',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'STARTERS 91',
#   'url': 'https://www.codechef.com/START91',
#   'start_time': '2023-05-24 14:30:00 UTC',
#   'end_time': '2023-05-24 16:30:00 UTC',
#   'duration': '7200',
#   'site': 'CodeChef',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'STARTERS 92',
#   'url': 'https://www.codechef.com/START92',
#   'start_time': '2023-05-31 14:30:00 UTC',
#   'end_time': '2023-05-31 16:30:00 UTC',
#   'duration': '7200',
#   'site': 'CodeChef',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'},
#  {'name': 'American Express Makeathon 2023',
#   'url': 'https://www.hackerearth.com/challenges/hackathon/american-express-makeathon-2023/',
#   'start_time': '2023-06-02T12:30:00.000Z',
#   'end_time': '2023-06-18T18:29:00.000Z',
#   'duration': '1403940.0',
#   'site': 'HackerEarth',
#   'in_24_hours': 'No',
#   'status': 'BEFORE'}]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3. Convert json data into *pandas* data frame.

# %%
# Write your code here
df3 = pd.DataFrame(result)
df3
# Out:
#                                                  name  \
# 0                                       ProjectEuler+
# 1                                  NuHarbor Hackathon
# 2                          HCL Volt MX Hackathon 2023
# 3                 Namma Yatri Open Mobility Challenge
# 4                           DAO Global Hackathon 2023
# 5   ICPC 2023 Online Spring Challenge powered by H...
# 6                       UTPC Spring 2023 Contest (HS)
# 7                       UTPC Spring 2023 Open Contest
# 8                                  Weekly Contest 341
# 9                            Consensus 2023 Hackathon
# 10               Junglee CodeFest: Unleash Your Skill
# 11                                        Starters 86
# 12                                Airbus Aerothon 5.0
# 13  Educational Codeforces Round 147 (Rated for Di...
# 14                           Amazon ML Challenge 2023
# 15  Tokio Marine & Nichido Fire Insurance Programm...
# 16  ALGO ARTIS Programming Contest 2023（AtCoder He...
# 17                                    Tectone23 Hacks
# 18                                        Starters 87
# 19  ユニークビジョンプログラミングコンテスト2023 春 (AtCoder Beginner C...
# 20                               Biweekly Contest 103
# 21                          Codeforces Round (Div. 2)
# 22                          Codeforces Round (Div. 1)
# 23                          AtCoder Grand Contest 062
# 24                                        STARTERS 88
# 25                                        STARTERS 89
# 26  パナソニックグループプログラミングコンテスト2023（AtCoder Beginner Co...
# 27                        AtCoder Regular Contest 160
# 28                                   LGBTQIA+ Matters
# 29                                        STARTERS 90
# 30                                        STARTERS 91
# 31                                        STARTERS 92
# 32                    American Express Makeathon 2023
#
#                                                   url  \
# 0        https://hackerrank.com/contests/projecteuler
# 1                   https://polyglot.hackerearth.com/
# 2                     https://voltmx.hackerearth.com/
# 3   https://www.hackerearth.com/challenges/hackath...
# 4         https://daoglobalhackathon.hackerearth.com/
# 5     https://codeforces.com/contestRegistration/1813
# 6       https://codeforces.com/gymRegistration/104312
# 7       https://codeforces.com/gymRegistration/104294
# 8     https://leetcode.com/contest/weekly-contest-341
# 9              https://web3athon2023.hackerearth.com/
# 10  https://www.hackerearth.com/challenges/competi...
# 11                   https://www.codechef.com/START86
# 12  https://www.hackerearth.com/challenges/competi...
# 13    https://codeforces.com/contestRegistration/1821
# 14  https://www.hackerearth.com/challenges/competi...
# 15                 https://atcoder.jp/contests/abc299
# 16                 https://atcoder.jp/contests/ahc020
# 17  https://www.hackerearth.com/challenges/hackath...
# 18                   https://www.codechef.com/START87
# 19                 https://atcoder.jp/contests/abc300
# 20  https://leetcode.com/contest/biweekly-contest-103
# 21    https://codeforces.com/contestRegistration/1818
# 22    https://codeforces.com/contestRegistration/1817
# 23                 https://atcoder.jp/contests/agc062
# 24                   https://www.codechef.com/START88
# 25                   https://www.codechef.com/START89
# 26                 https://atcoder.jp/contests/abc301
# 27                 https://atcoder.jp/contests/arc160
# 28  https://www.hackerearth.com/challenges/hackath...
# 29                   https://www.codechef.com/START90
# 30                   https://www.codechef.com/START91
# 31                   https://www.codechef.com/START92
# 32  https://www.hackerearth.com/challenges/hackath...
#
#                   start_time                  end_time     duration  \
# 0   2014-07-07T15:38:00.000Z  2024-07-30T18:30:00.000Z  317616720.0
# 1   2023-02-25T04:01:00.000Z  2023-04-17T10:00:00.000Z    4427940.0
# 2   2023-03-13T19:00:00.000Z  2023-05-15T06:59:00.000Z    5399940.0
# 3   2023-03-28T12:30:00.000Z  2023-04-30T18:29:00.000Z    2872740.0
# 4   2023-04-10T12:00:00.000Z  2023-05-07T22:00:00.000Z    2368800.0
# 5   2023-04-13T11:00:00.000Z  2023-04-27T11:00:00.000Z      1209600
# 6   2023-04-15T18:00:00.000Z  2023-04-15T21:00:00.000Z        10800
# 7   2023-04-15T18:00:00.000Z  2023-04-15T23:00:00.000Z        18000
# 8   2023-04-16T02:30:00.000Z  2023-04-16T04:00:00.000Z         5400
# 9   2023-04-17T04:00:00.000Z  2023-06-01T03:59:00.000Z    3887940.0
# 10  2023-04-19T12:30:00.000Z  2023-04-23T18:25:00.000Z     366900.0
# 11   2023-04-19 14:30:00 UTC   2023-04-19 16:30:00 UTC         7200
# 12  2023-04-20T05:30:00.000Z  2023-04-30T17:30:00.000Z     907200.0
# 13  2023-04-20T14:35:00.000Z  2023-04-20T16:50:00.000Z         8100
# 14  2023-04-20T18:30:00.000Z  2023-04-23T18:29:00.000Z     259140.0
# 15  2023-04-22T12:00:00.000Z  2023-04-22T13:40:00.000Z         6000
# 16  2023-04-23T06:00:00.000Z  2023-04-23T10:00:00.000Z        14400
# 17  2023-04-24T13:39:00.000Z  2023-05-19T18:25:00.000Z    2177160.0
# 18   2023-04-26 14:30:00 UTC   2023-04-26 16:30:00 UTC         7200
# 19  2023-04-29T12:00:00.000Z  2023-04-29T13:40:00.000Z         6000
# 20  2023-04-29T14:30:00.000Z  2023-04-29T16:00:00.000Z         5400
# 21  2023-04-29T14:35:00.000Z  2023-04-29T16:50:00.000Z         8100
# 22  2023-04-29T14:35:00.000Z  2023-04-29T16:50:00.000Z         8100
# 23  2023-04-30T12:00:00.000Z  2023-04-30T15:00:00.000Z        10800
# 24   2023-05-03 14:30:00 UTC   2023-05-03 16:30:00 UTC         7200
# 25   2023-05-10 14:30:00 UTC   2023-05-10 16:30:00 UTC         7200
# 26  2023-05-13T12:00:00.000Z  2023-05-13T13:40:00.000Z         6000
# 27  2023-05-14T12:00:00.000Z  2023-05-14T14:00:00.000Z         7200
# 28  2023-05-17T10:00:00.000Z  2023-05-17T12:00:00.000Z       7200.0
# 29   2023-05-17 14:30:00 UTC   2023-05-17 16:30:00 UTC         7200
# 30   2023-05-24 14:30:00 UTC   2023-05-24 16:30:00 UTC         7200
# 31   2023-05-31 14:30:00 UTC   2023-05-31 16:30:00 UTC         7200
# 32  2023-06-02T12:30:00.000Z  2023-06-18T18:29:00.000Z    1403940.0
#
#                site in_24_hours  status
# 0        HackerRank          No  CODING
# 1       HackerEarth          No  CODING
# 2       HackerEarth          No  CODING
# 3       HackerEarth          No  CODING
# 4       HackerEarth          No  CODING
# 5        CodeForces         Yes  CODING
# 6   CodeForces::Gym         Yes  CODING
# 7   CodeForces::Gym         Yes  CODING
# 8          LeetCode         Yes  BEFORE
# 9       HackerEarth          No  BEFORE
# 10      HackerEarth          No  BEFORE
# 11         CodeChef          No  BEFORE
# 12      HackerEarth          No  BEFORE
# 13       CodeForces          No  BEFORE
# 14      HackerEarth          No  BEFORE
# 15          AtCoder          No  BEFORE
# 16          AtCoder          No  BEFORE
# 17      HackerEarth          No  BEFORE
# 18         CodeChef          No  BEFORE
# 19          AtCoder          No  BEFORE
# 20         LeetCode          No  BEFORE
# 21       CodeForces          No  BEFORE
# 22       CodeForces          No  BEFORE
# 23          AtCoder          No  BEFORE
# 24         CodeChef          No  BEFORE
# 25         CodeChef          No  BEFORE
# 26          AtCoder          No  BEFORE
# 27          AtCoder          No  BEFORE
# 28      HackerEarth          No  BEFORE
# 29         CodeChef          No  BEFORE
# 30         CodeChef          No  BEFORE
# 31         CodeChef          No  BEFORE
# 32      HackerEarth          No  BEFORE

# %%
# A simple script in python to get info about upcoming and ongoing competitive coding contests

# Importing
import requests
import json
import datetime
import time

# API
data = requests.get('https://kontests.net/api/v1/all')

# getting result using json
result = json.loads(data.text)

# Dataframe using result
contest_dataframe = pd.DataFrame(result)

# Get 24hour data
hour = contest_dataframe[contest_dataframe['in_24_hours'] == 'Yes']
# Out:
# (5, 8)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3
# ```
#
# </details>

# %% [markdown]
#                                 Copyright © 2020 IBM Corporation. All rights reserved.
